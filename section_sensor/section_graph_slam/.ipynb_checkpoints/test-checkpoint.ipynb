# %%
f = open('log.txt','r')
for i in f:
    print(i) # 改行込み
    # print(i.strip()) # 改行なし
f.close()
# Out:
# x 0 0 -3 0
#
# z 0 1 1.924511624714355 -0.03676821846037173 3.122942682599561
#
# x 1 0.5931695576792215 -2.9219077462387197 0.2617993877991494
#
# z 1 1 1.1439219354682224 -0.26589722659897363 3.021830298661395
#
# x 2 1.1459155902616462 -2.6929528429951586 0.5235987755982988
#
# z 2 1 0.5593296308314594 -0.9249491887527644 2.5883069230500926
#
# z 2 2 5.6084888753457225 0.8919097648623675 -1.784821617306677
#
# x 3 1.6205693690827907 -2.328738188559498 0.7853981633974483
#
# z 3 2 4.362727768134887 0.7308808967170638 -1.7589776992102153
#
# x 4 2.2137389267620122 -1.301338377155929 1.308996938995747
#
# z 4 2 4.267269754756563 0.31406432819210744 -1.574644162579261
#
# z 4 3 5.842755427300147 0.9001621854168328 -1.0487401540224912
#
# x 5 2.291831180523293 -0.7081688194767076 1.5707963267948963
#
# z 5 2 2.7806166926752196 0.08184802354112496 -1.525834035717523
#
# z 5 3 5.743336026981948 0.7061649946119057 -0.9501721649329166
#
# ...

# %%
f = open('test.txt','w')
a = 10
f.write('hoge'
f.close()

# %%
f = open('test.txt','r') # ファイルが存在しなければ新たに作成される
for i in f:
    print(i) # 改行込み
    # print(i.strip()) # 改行なし
f.close()
# Out:
# hoge

# %%
# 今日の日付
from datetime import datetime
today = datetime.now().strftime("%Y%m%d")
print(today)
# Out:
# 20200616
