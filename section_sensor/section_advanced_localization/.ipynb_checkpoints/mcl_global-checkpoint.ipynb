# %%
import sys
sys.path.append('../scripts/')
from mcl import*

# %%
class GlobalMcl(Mcl):
    def __init__(self, envmap,  num, motion_noise_stds = {"nn":0.19, "no":0.001, "on":0.13, "oo":0.2},\
                distance_dev_rate = 0.14, direction_dev = 0.05):
        super().__init__(envmap, np.array([0,0,0]).T, num, motion_noise_stds, distance_dev_rate, direction_dev)
        for p in self.particles:
            p.pose = np.array([np.random.uniform(-5.0, 5.0), np.random.uniform(-5.0, 5.0), np.random.uniform(-math.pi, math.pi)]).T

# %%
def trial(animation):
    time_interval = 0.1
    world = World(30,time_interval,debug = not animation)
    
    m = Map()
    for ln in [(-4,2),(2,-3),(3,3)]: m.append_landmark(Landmark(*ln))
    world.append(m)
    
    initial_pose = np.array([np.random.uniform(-5.0, 5.0), np.random.uniform(-5.0, 5.0), np.random.uniform(-math.pi, math.pi)]).T
    pf = GlobalMcl(m,  100)
    a = EstimationAgent(time_interval,0.2,10.0 / 180 * math.pi,pf)
    r = Robot(initial_pose,sensor = Camera(m),agent = a,color = "red") # このカメラ、ファントム、オクルージョン...全部込み込み
    world.append(r)
    
    world.draw()
    return (r.pose, pf.pose)
    
trial(True)
# Out:
# <img src="data:image/png;base64,..." width="288">
# (array([-1.39028761,  2.84895109, -2.24828551]), array([0, 0, 0]))

# %%
if __name__ =='__main__':
    ok = 0
    for i in range(1000):
        actual, estm = trial(False)
        diff = math.sqrt((actual[0] - estm[0]) ** 2 + (actual[1] - estm[1]) **2)
        print("真:", actual, "推定:", estm, "誤差:", diff)
        if diff <= 0:
            ok += 1
            
    ok
# Out:
# <div id='5cbc8190-e15e-4bd3-97e5-906259d04ecd'></div>
# 真: [-2.62731944  1.01431458 17.14593988] 推定: [ 1.22366271 -0.18740139 16.42862364] 誤差: 4.034127516932113
# <div id='1881d03d-de92-4bf0-af0e-fbf72e1e657a'></div>
# 真: [-5.44316097  3.57624592 22.60628138] 推定: [ 0.22863258  2.8633239  15.68931429] 誤差: 5.7164236980044185
# <div id='7d854bc1-cbfa-4572-adef-1f78d82815ec'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3488cb0420e4> in <module>
#       2     ok = 0
#       3     for i in range(1000):
# ----> 4         actual, estm = trial(False)
#       5         diff = math.sqrt((actual[0] - estm[0]) ** 2 + (actual[1] - estm[1]) **2)
#       6         print("真:", actual, "推定:", estm, "誤差:", diff)
#
# <ipython-input-12-7bba8e67388b> in trial(animation)
#      13     world.append(r)
#      14
# ---> 15     world.draw()
#      16     return (r.pose, pf.pose)
#      17
#
# ~/github/probabilistic_robotics_training/section_sensor/scripts/ideal_robot.py in draw(self)
#      40
#      41         if self.debug:
# ---> 42             for i in range(1000):self.one_step(i,elems,ax) # デバッグ時にアニメーションをさせない
#      43         else:
#      44             # FuncAnimation内をupdate
#
# ~/github/probabilistic_robotics_training/section_sensor/scripts/ideal_robot.py in one_step(self, i, elems, ax)
#      55         elems.append(ax.text(-4.4,4.5,time_str,fontsize = 10)) # 経過時間をどこに表示するか設定
#      56         for obj in self.objects: # objectsはIdealRobot
# ---> 57             obj.draw(ax,elems) # class IdealRobotで描く
#      58             if hasattr(obj,"one_step"): obj.one_step(self.time_interval) # 姿勢の更新　IdealRobotのone_step
#      59             # obj.one_stepはIdealRobotのonestep
#
# ~/github/probabilistic_robotics_training/section_sensor/scripts/ideal_robot.py in draw(self, ax, elems)
#     154
#     155     def draw(self,ax,elems):            # ランドマークの作図
# --> 156         for lm in self.landmarks: lm.draw(ax,elems)
#     157
#     158 # In[7]:
#
# ~/github/probabilistic_robotics_training/section_sensor/scripts/ideal_robot.py in draw(self, ax, elems)
#     137     def draw(self,ax,elems):
#     138         # s:点のサイズ
# --> 139         c = ax.scatter(self.pos[0],self.pos[1],s = 100,marker = "*",label = "landmarks",color = "orange")
#     140         elems.append(c)
#     141         elems.append(ax.text(self.pos[0],self.pos[1],"id" + str(self.id),fontsize = 10))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4460             x, y, s, c, colors, edgecolors, linewidths = \
#    4461                 cbook._combine_masks(
# -> 4462                     x, y, s, c, colors, edgecolors, linewidths)
#    4463
#    4464         scales = s   # Renamed for readability below.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _combine_masks(*args)
#    1120             x = np.asanyarray(x)
#    1121             if x.ndim == 1:
# -> 1122                 x = safe_masked_invalid(x)
#    1123                 seqlist[i] = True
#    1124                 if np.ma.is_masked(x):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#     802
#     803     try:
# --> 804         xm = np.ma.masked_invalid(x, copy=False)
#     805         xm.shrink_mask()
#     806     except TypeError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in masked_invalid(a, copy)
#    2377         condition = ~(np.isfinite(a))
#    2378         cls = MaskedArray
# -> 2379     result = a.view(cls)
#    2380     result._mask = condition
#    2381     return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in view(self, dtype, type, fill_value)
#    3149             try:
#    3150                 if issubclass(dtype, ndarray):
# -> 3151                     output = ndarray.view(self, dtype)
#    3152                     dtype = None
#    3153                 else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in __array_finalize__(self, obj)
#    2942         """
#    2943         # Get main attributes.
# -> 2944         self._update_from(obj)
#    2945
#    2946         # We have to decide how to initialize self.mask, based on
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in _update_from(self, obj)
#    2921         # We need to copy the _basedict to avoid backward propagation
#    2922         _optinfo = {}
# -> 2923         _optinfo.update(getattr(obj, '_optinfo', {}))
#    2924         _optinfo.update(getattr(obj, '_basedict', {}))
#    2925         if not isinstance(obj, MaskedArray):
#
# KeyboardInterrupt:
