# %%
from scipy.stats import expon, norm,uniform # 指数分布の機能を提供するオブジェクト
import matplotlib.pyplot as plt
s = expon(scale = 1.0 / (1e-100 + 5))
t = s.rvs()
u = []
for i in range(100):
    u.append(s.rvs())
print(t)
plt.plot(u)
plt.show(u)
# Out:
# 0.20594637884439965

# %%
a = expon()
u = []
for i in range(100):
    u.append(a.rvs())
b = a.rvs()
print(sum(u)/100)
plt.plot(u)
plt.show()
print(b)
# Out:
# 0.8235194759835116
# 1.3655068516064475

# %%
zs = range(0,100)
#ys = [p(z) for z in zs]# gaussianp(z)において、mu,sigmaに近いものは大きく、遠いものは小さい値が取れる
plt.plot(zs,u)
plt.show()

# %%
a = uniform(scale = 10)
b = []
for i in range(100):
        b.append(a.rvs())
        
print(min(b))
# Out:
# 0.1798050591814382

# %%
print(max(b))
# Out:
# 9.661567673870397

# %%
a = uniform.rvs(scale = 10)
print(a)
# Out:
# 8.540966542725553
